# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
datas=pd.read_csv("E:\\chrome_downloads\\Microsoft Dataset.csv")
datas.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060055  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062199   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063272   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061663    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060591    47894400

# %%
x=datas.iloc[:,2:3].values
y=datas.iloc[:,3].values

# %%
lin=LinearRegression()
lin.fit(x,y)
# Out:
# LinearRegression()

# %%
poly=PolynomialFeatures(degree=4)
x_poly=poly.fit_transform(x)
poly.fit(x_poly,y)
lin2=LinearRegression()
lin2.fit(x_poly,y)
print(lin.predict(x))
# Out:
# [1.55079430e-02 1.63591746e-02 1.72104062e-02 ... 4.22530824e+02
#  4.16019084e+02 4.08497273e+02]

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,lin.predict(x),color='red')
plt.title('Linear Regression')
plt.xlabel('High')
plt.ylabel('Low')
# Out:
# Text(0, 0.5, 'Low')

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,lin2.predict(poly.fit_transform(x)),color='red')
plt.title('polynomial Regression')
plt.xlabel('High')
plt.ylabel('Low')
print(lin2.predict(poly.fit_transform(x)))
# Out:
# [1.81995161e-02 1.90530232e-02 1.99065303e-02 ... 4.24859286e+02
#  4.18113859e+02 4.10337931e+02]
